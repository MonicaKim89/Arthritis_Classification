# %% [markdown]
# <a href="https://colab.research.google.com/github/MonicaKim89/Arthritis_Classification/blob/main/%5B0304%5D_use_this_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Projects/knee/yolov5
# Out:
# /content/drive/MyDrive/Projects/knee/yolov5

# %%
# !pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 4.2 MB/s

# %%
# !python yolov5_detect_crop.py --weights /content/drive/MyDrive/Projects/knee/knee_best.pt --img 224 --conf 0.6 --source /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.6, device='', exist_ok=False, img_size=224, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4', update=False, view_img=False, weights=['/content/drive/MyDrive/Projects/knee/knee_best.pt'])
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9012867R.jpg: Done
# Done
# image 2/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9025994L.jpg: Done
# image 3/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9031426R.jpg: Done
# image 4/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9039627L.jpg: Done
# Done
# image 5/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9048789L.jpg: Done
# Done
# image 6/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9049007L.jpg: Done
# Done
# image 7/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9049507L.jpg: Done
# Done
# image 8/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9053047L.jpg: Done
# image 9/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9055836R.jpg: Done
# image 10/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9057150L.jpg: Done
# image 11/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9065272L.jpg: Done
# Done
# image 12/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9069393L.jpg: Done
# image 13/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9070207R.jpg: Done
# Done
# image 14/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9074437L.jpg: Done
# Done
# image 15/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9075815L.jpg: Done
# image 16/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9081306L.jpg: Done
# Done
# image 17/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9086204R.jpg: Done
# image 18/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9086868L.jpg: Done
# Done
# image 19/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9095103L.jpg: Done
# image 20/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9101066R.jpg: Done
# Done
# image 21/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9101854L.jpg: Done
# Done
# image 22/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9103783L.jpg: Done
# image 23/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9114036R.jpg: Done
# Done
# image 24/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9115049L.jpg: Done
# Done
# image 25/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9118430R.jpg: Done
# image 26/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9127180L.jpg: Done
# image 27/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9144384R.jpg: Done
# Done
# image 28/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9156694R.jpg: Done
# Done
# image 29/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9158391R.jpg: Done
# image 30/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9160801R.jpg: Done
# Done
# image 31/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9167541L.jpg: Done
# Done
# image 32/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9171580R.jpg: Done
# image 33/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9173013L.jpg: Done
# Done
# image 34/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9173792R.jpg: Done
# Done
# image 35/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9177337R.jpg: Done
# image 36/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9184628L.jpg: Done
# image 37/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9194300L.jpg: Done
# image 38/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9197466L.jpg: Done
# image 39/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9204055R.jpg: Done
# Done
# image 40/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9208400R.jpg: Done
# image 41/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9215922R.jpg: Done
# image 42/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9218916L.jpg: Done
# Done
# image 43/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9218935R.jpg: Done
# image 44/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9225592L.jpg: Done
# image 45/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9230284L.jpg: Done
# image 46/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9230504R.jpg: Done
# Done
# image 47/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9235666R.jpg: Done
# Done
# image 48/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9250129R.jpg: Done
# Done
# image 49/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9254422L.jpg: Done
# image 50/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9256759R.jpg: Done
# Done
# image 51/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9257048L.jpg: Done
# Done
# image 52/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9259866L.jpg: Done
# Done
# Done
# image 53/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_
251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9772692L.jpg: Done
# image 195/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9775951L.jpg: Done
# Done
# image 196/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9778632R.jpg: Done
# image 197/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9780662R.jpg: Done
# Done
# image 198/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9781749R.jpg: Done
# Done
# image 199/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9787693R.jpg: Done
# Done
# image 200/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9788608R.jpg: Done
# Done
# image 201/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9797352L.jpg: Done
# Done
# image 202/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9799305L.jpg: Done
# image 203/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9800285R.jpg: Done
# image 204/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9800368L.jpg: Done
# Done
# image 205/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9810432R.jpg: Done
# Done
# image 206/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9813958R.jpg: Done
# Done
# image 207/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9814262R.jpg: Done
# image 208/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9818359L.jpg: Done
# image 209/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9820479L.jpg: Done
# image 210/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9824005L.jpg: Done
# image 211/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9828555L.jpg: Done
# image 212/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9841033R.jpg: Done
# Done
# image 213/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9842579L.jpg: Done
# Done
# image 214/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9843822R.jpg: Done
# Done
# image 215/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9844838R.jpg: Done
# Done
# image 216/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9847541R.jpg: Done
# Done
# image 217/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9849852R.jpg: Done
# Done
# Done
# image 218/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9851309L.jpg: Done
# image 219/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9856356L.jpg: Done
# image 220/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9858216R.jpg: Done
# Done
# image 221/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9858840R.jpg: Done
# Done
# image 222/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9861493R.jpg: Done
# image 223/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9886298L.jpg: Done
# image 224/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9896743L.jpg: Done
# Done
# image 225/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9900761R.jpg: Done
# image 226/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9910391R.jpg: Done
# image 227/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9912946L.jpg: Done
# image 228/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9917284L.jpg: Done
# image 229/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9919646L.jpg: Done
# Done
# image 230/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9919646R.jpg: Done
# image 231/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9924274L.jpg: Done
# image 232/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9928082L.jpg: Done
# image 233/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9930620L.jpg: Done
# Done
# image 234/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9932578R.jpg: Done
# image 235/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9933836R.jpg: Done
# image 236/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9938636R.jpg: Done
# Done
# image 237/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9941323L.jpg: Done
# image 238/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9942319R.jpg: Done
# image 239/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9950790R.jpg: Done
# Done
# image 240/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9951449L.jpg: Done
# image 241/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9961951L.jpg: Done
# Done
# image 242/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9964731L.jpg: Done
# image 243/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9967719L.jpg: Done
# Done
# image 244/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9971710L.jpg: Done
# image 245/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9973713L.jpg: Done
# Done
# image 246/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9975485R.jpg: Done
# image 247/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9978026L.jpg: Done
# image 248/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9991313L.jpg: Done
# image 249/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9992318L.jpg: Done
# image 250/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9996865L.jpg: Done
# image 251/251 /content/drive/MyDrive/Projects/knee/knee_dataset_prepro/4/4_9997856L.jpg: Done
# Results saved to runs/detect/exp13
# Done. (12.422s)

# %%
### yolov5 detected object cropper
### set result location
### rename the file

import argparse
import os
import time
from pathlib import Path
import numpy as np
import random

import cv2
import torch
import torch.backends.cudnn as cudnn
from numpy import random

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized


cor_list =[]

def detect(save_img=False):
    source, weights, view_img, save_txt, imgsz = opt.source, opt.weights, opt.view_img, opt.save_txt, opt.img_size
    webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(
        ('rtsp://', 'rtmp://', 'http://'))

    # Directories
    save_dir = Path(increment_path(Path(opt.project) / opt.name, exist_ok=opt.exist_ok))  # increment run
    (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir

    # Initialize
    set_logging()
    device = select_device(opt.device)
    half = device.type != 'cpu'  # half precision only supported on CUDA

    # Load model
    model = attempt_load(weights, map_location=device)  # load FP32 model
    stride = int(model.stride.max())  # model stride
    imgsz = check_img_size(imgsz, s=stride)  # check img_size
    if half:
        model.half()  # to FP16

    # Second-stage classifier
    classify = False
    if classify:
        modelc = load_classifier(name='resnet101', n=2)  # initialize
        modelc.load_state_dict(torch.load('weights/resnet101.pt', map_location=device)['model']).to(device).eval()

    # Set Dataloader
    vid_path, vid_writer = None, None
    if webcam:
        view_img = check_imshow()
        cudnn.benchmark = True  # set True to speed up constant image size inference
        dataset = LoadStreams(source, img_size=imgsz, stride=stride)
    else:
        save_img = True
        dataset = LoadImages(source, img_size=imgsz, stride=stride)

    # Get names and colors
    names = model.module.names if hasattr(model, 'module') else model.names
    colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]

    # Run inference
    if device.type != 'cpu':
        model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))  # run once
    t0 = time.time()
    for path, img, im0s, vid_cap in dataset:
        img = torch.from_numpy(img).to(device)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)

        # Inference
        t1 = time_synchronized()
        pred = model(img, augment=opt.augment)[0]

        # Apply NMS
        pred = non_max_suppression(pred, opt.conf_thres, opt.iou_thres, classes=opt.classes, agnostic=opt.agnostic_nms)
        t2 = time_synchronized()

        # Apply Classifier
        if classify:
            pred = apply_classifier(pred, modelc, img, im0s)

        # Process detections
        for i, det in enumerate(pred):  # detections per image
            if webcam:  # batch_size >= 1
                p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
            else:
                p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)

            p = Path(p)  # to Path
            save_path = str(save_dir / p.name)  # img.jpg
            txt_path = str(save_dir / 'labels' / p.stem) + ('' if dataset.mode == 'image' else f'_{frame}')  # img.txt
            s += '%gx%g ' % img.shape[2:]  # print string
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

                # Write results
                 # Write results
                for *xyxy, conf, cls in det:
                    if save_txt:  # Write to file
                        xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                        with open(txt_path + '.txt', 'a') as f:
                            f.write(('%g ' * 5 + '\n') % (cls, *xywh))  # label format
                    
                    if save_img or view_img:  # Add bbox to image
                        label = '%s %.2f' % (names[int(cls)], conf)
                        # plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=3)
                    
                    save_obj = True
                    
                    if save_obj:
                        cordinates = (int(xyxy[0]), int(xyxy[1]), int(xyxy[2] - xyxy[0]), int(xyxy[3] - xyxy[1]))
                        # print(cordinates)
                        cor_list.append(cordinates)
                        for k in range(len(det)):
                            x,y,w,h=int(xyxy[0]), int(xyxy[1]), int(xyxy[2] - xyxy[0]), int(xyxy[3] - xyxy[1])
                           
                            img_ = im0.astype(np.uint8)
                            crop_img=img_[y:y+ h, x:x + w]                          
                                
                            #!!rescale image !!!

                            random_num = random.randint(1,100)
                            filename=p.name
                            # print(filename)
                            filepath='/content/drive/MyDrive/Projects/knee/knee_yolo_detect/4/'
                            # print(filepath+'{}_'.format(random_num)+filename)
                            cv2.imwrite(filepath+'{}_'.format(random_num)+filename, crop_img) 

                            ####cordinates####
                            f = open('/content/drive/MyDrive/Projects/knee/knee_yolo_txt/4/{}.txt'.format(filename), 'w')
                            f.write(str(cordinates))
                            f.close()

                            
                        else:
                            # print("There is no detected object")
                            print("Done")
                            continue

            # Print time (inference + NMS)
            # print(f'{s}Done. ({t2 - t1:.3f}s)')
            # print(cor_list)
            f = open('/content/drive/MyDrive/Projects/knee/knee_yolo_txt/con/4/4_test.txt', 'w')
            for i in cor_list:
                f.write(filename.split('.jpg')[0]+'   '+str(i)+'\n')
            f.close()

            # Stream results
            if view_img:
                cv2.imshow(str(p), im0)
                cv2.waitKey(1)  # 1 millisecond

            # Save results (image with detections)
            if save_img:
                if dataset.mode == 'image':
                    cv2.imwrite(save_path, im0)
                else:  # 'video'
                    if vid_path != save_path:  # new video
                        vid_path = save_path
                        if isinstance(vid_writer, cv2.VideoWriter):
                            vid_writer.release()  # release previous video writer

                        fourcc = 'mp4v'  # output video codec
                        fps = vid_cap.get(cv2.CAP_PROP_FPS)
                        w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                        h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                        vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*fourcc), fps, (w, h))
                    vid_writer.write(im0)

    if save_txt or save_img:
        s = f"\n{len(list(save_dir.glob('labels/*.txt')))} labels saved to {save_dir / 'labels'}" if save_txt else ''
        print(f"Results saved to {save_dir}{s}")

    print(f'Done. ({time.time() - t0:.3f}s)')


if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--weights', nargs='+', type=str, default='yolov5s.pt', help='model.pt path(s)')
    parser.add_argument('--source', type=str, default='data/images', help='source')  # file/folder, 0 for webcam
    parser.add_argument('--img-size', type=int, default=640, help='inference size (pixels)')
    parser.add_argument('--conf-thres', type=float, default=0.25, help='object confidence threshold')
    parser.add_argument('--iou-thres', type=float, default=0.45, help='IOU threshold for NMS')
    parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
    parser.add_argument('--view-img', action='store_true', help='display results')
    parser.add_argument('--save-txt', action='store_true', help='save results to *.txt')
    parser.add_argument('--save-conf', action='store_true', help='save confidences in --save-txt labels')
    parser.add_argument('--classes', nargs='+', type=int, help='filter by class: --class 0, or --class 0 2 3')
    parser.add_argument('--agnostic-nms', action='store_true', help='class-agnostic NMS')
    parser.add_argument('--augment', action='store_true', help='augmented inference')
    parser.add_argument('--update', action='store_true', help='update all models')
    parser.add_argument('--project', default='runs/detect', help='save results to project/name')
    parser.add_argument('--name', default='exp', help='save results to project/name')
    parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
    opt = parser.parse_args()
    print(opt)
    check_requirements(exclude=('pycocotools', 'thop'))

    with torch.no_grad():
        if opt.update:  # update all models (to fix SourceChangeWarning)
            for opt.weights in ['yolov5s.pt', 'yolov5m.pt', 'yolov5l.pt', 'yolov5x.pt']:
                detect()
                strip_optimizer(opt.weights)
        else:
            detect()
