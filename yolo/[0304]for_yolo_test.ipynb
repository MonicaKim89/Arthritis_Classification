15 /content/drive/MyDrive/Projects/knee/for_yolov5_test/4_9101854L.jpg: /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/88_4_9101854L.jpg
# There is no detected object
# 224x224 1 knee, Done. (0.012s)
# [(2, 1, 222, 163), (3, 5, 219, 167), (1, 36, 222, 165), (0, 2, 224, 38), (4, 8, 220, 166), (2, 33, 221, 164), (0, 0, 224, 37), (10, 188, 207, 35), (1, 19, 223, 167), (5, 5, 212, 201), (5, 53, 217, 167), (5, 51, 219, 170), (2, 28, 222, 162), (2, 19, 221, 163), (5, 1, 211, 203), (4, 6, 220, 168)]
# image 14/15 /content/drive/MyDrive/Projects/knee/for_yolov5_test/4_9114036R.jpg: /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/18_4_9114036R.jpg
# /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/56_4_9114036R.jpg
# There is no detected object
# /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/47_4_9114036R.jpg
# /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/60_4_9114036R.jpg
# There is no detected object
# 224x224 2 knees, Done. (0.012s)
# [(2, 1, 222, 163), (3, 5, 219, 167), (1, 36, 222, 165), (0, 2, 224, 38), (4, 8, 220, 166), (2, 33, 221, 164), (0, 0, 224, 37), (10, 188, 207, 35), (1, 19, 223, 167), (5, 5, 212, 201), (5, 53, 217, 167), (5, 51, 219, 170), (2, 28, 222, 162), (2, 19, 221, 163), (5, 1, 211, 203), (4, 6, 220, 168), (4, 8, 216, 166), (1, 76, 217, 146)]
# image 15/15 /content/drive/MyDrive/Projects/knee/for_yolov5_test/4_9115049L.jpg: /content/drive/MyDrive/Projects/knee/for_yolov5_test/result/58_4_9115049L.jpg
# There is no detected object
# 224x224 1 knee, Done. (0.012s)
# [(2, 1, 222, 163), (3, 5, 219, 167), (1, 36, 222, 165), (0, 2, 224, 38), (4, 8, 220, 166), (2, 33, 221, 164), (0, 0, 224, 37), (10, 188, 207, 35), (1, 19, 223, 167), (5, 5, 212, 201), (5, 53, 217, 167), (5, 51, 219, 170), (2, 28, 222, 162), (2, 19, 221, 163), (5, 1, 211, 203), (4, 6, 220, 168), (4, 8, 216, 166), (1, 76, 217, 146), (3, 4, 220, 169)]
# Results saved to runs/detect/exp2
# Done. (0.618s)

# %%
cord=[]
f = open('/content/drive/MyDrive/Projects/knee/for_yolov5_test/result/test.txt', 'r')
lines = f.readlines()
for line in lines:
    k = line.split('\n')[0]
    k = k.replace('(','')
    k = k.replace(')','')
    k = k.replace(',','')
    cord.append(k)
cord
# Out:
# ['2 1 222 163',
#  '3 5 219 167',
#  '1 36 222 165',
#  '0 2 224 38',
#  '4 8 220 166',
#  '2 33 221 164',
#  '0 0 224 37',
#  '10 188 207 35',
#  '1 19 223 167',
#  '5 5 212 201',
#  '5 53 217 167',
#  '5 51 219 170',
#  '2 28 222 162',
#  '2 19 221 163',
#  '5 1 211 203',
#  '4 6 220 168',
#  '4 8 216 166',
#  '1 76 217 146',
#  '3 4 220 169']

# %%
x = int(cord[0].split(' ')[0])
y = int(cord[0].split(' ')[1])
w = int(cord[0].split(' ')[2])
h = int(cord[0].split(' ')[3])

# %%
import math
import cv2
import matplotlib.pylab as plt

# %%
def show(img):
    #사이즈
    plt.figure(figsize = (10,8))
    #xticks/yticks - 눈금표
    plt.xticks([])
    plt.yticks([])
    #코랩에서 안돌아감 주의
    plt.imshow(img, cmap= 'gray')
    plt.show()

# %%
import cv2
img = cv2.imread('/content/drive/MyDrive/Projects/knee/for_yolov5_test/0_9051960R.jpg')

show(img)

# %%
img_ = img.copy()
img_ = cv2.rectangle(img_, (x,y),(x+w,y+h), (0,0,255), 1)

show(img_)

# %%
img_ = img.copy()
# img_ = cv2.rectangle(img_, (x,y),(x+w,y+h), (0,0,255), 1)
crop_img=img_[y:y+ h, x:x + w]  
show(crop_img)
