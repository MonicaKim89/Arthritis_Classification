# %%
# %cd C:\Users\yukir\Documents\GitHub\Sign_Recognition\py

from basic_preprocessing import *
from deeplearning_check import *
from machine_learning import *

gpu_check()
set_global_determinism(seed=SEED)

import os
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import matplotlib.pylab as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import glob
import math
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
from IPython.display import Image

import tensorflow as tf
import os
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
import keras

#cv
import cv2
import math
from PIL import Image
import math
from scipy import ndimage
import argparse
import imutils
import xml.etree.ElementTree as ET

import random 
from tqdm import tqdm
from skimage.io import imread, imshow
from skimage.transform import resize

#시각화
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
get_ipython().run_line_magic('matplotlib', 'inline')

import matplotlib.image as mpimg
from matplotlib import font_manager, rc
rc('font',family="consolas")
plt.rcParams["font.family"]="consolas" #plt 한글꺠짐
plt.rcParams["font.family"]="Arial" #외국어꺠짐
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
plt.rc('figure', figsize=(10,8))

sns.set(font="consolas", 
        rc={"axes.unicode_minus":False},style='darkgrid')

# %cd C:\Users\yukir\Documents\Monicas_workspace\Knee
# Out:
# C:\Users\yukir\Documents\GitHub\Sign_Recognition\py
# Using TensorFlow backend.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13867516626030713797
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7079203427046500490
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4726177792
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1514987625596626305
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16028433798415115367
# physical_device_desc: "device: XLA_GPU device"
# ]
# tf 2.2.0
# keras 2.3.0-tf
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# C:\Users\yukir\Documents\Monicas_workspace\Knee

# %%
set_global_determinism(seed=1337)

# %%
# process시각화 및 손실함수

def plot_it(history):
    '''function to plot training and validation error'''
    fig, ax = plt.subplots( figsize=(20,10))
    ax.plot(history.history['mae_in_months'])
    ax.plot(history.history['val_mae_in_months'])
    plt.title('Model Error')
    plt.ylabel('error')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    ax.grid(color='black')
    plt.show()
    fig = plt.gcf()
    fig.savefig("../03_model_visualization/"+model_name+".jpg")
    plt.close(fig)

# %% [markdown]
# ### DATA

# %%
train_dir = 'C:\\Users\\yukir\\Documents\\Monicas_workspace\\Knee\\dataset\\vgg_dataset\\org_preproc\\train'
test_dir = 'C:\\Users\\yukir\\Documents\\Monicas_workspace\\Knee\\dataset\\vgg_dataset\\org_preproc\\test'
val_dir = 'C:\\Users\\yukir\\Documents\\Monicas_workspace\\Knee\\dataset\\vgg_dataset\\org_preproc\\val'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
from keras import Input
train_generator = train_datagen.flow_from_directory(train_dir, batch_size=16, target_size=(224,224), color_mode='rgb')
val_generator = val_datagen.flow_from_directory(val_dir, batch_size=16, target_size=(224, 224), color_mode='rgb')
test_generator = test_datagen.flow_from_directory(test_dir,batch_size=16, target_size=(224, 224), color_mode='rgb')

input_tensor = Input(shape=(224, 224, 3), dtype='float32', name='input')
# Out:
# Found 5298 images belonging to 5 classes.
# Found 1614 images belonging to 5 classes.
# Found 1302 images belonging to 5 classes.

# %% [markdown]
# ### MODEL

# %%
from tensorflow.keras.applications import VGG16

def create_model():
    optimizer = Adam()

    x_input = tf.keras.Input(shape=(224, 224, 3), name="x_input_node")
    x = Conv2D(kernel_size=(5, 5), filters=16, padding='same', use_bias=False, dilation_rate=2)(x_input)
    x = BatchNormalization()(x)
    x1 = PReLU()(x)

    short_cut = MaxPool2D(pool_size=(2, 3))(x1)
    x = Conv2D(kernel_size=(5, 5), filters=16, padding='same', use_bias=False, dilation_rate=2)(short_cut)
    x = BatchNormalization()(x)
    x2 = PReLU()(x) + short_cut


    short_cut = MaxPool2D(pool_size=(2, 3))(x2)
    x = Conv2D(kernel_size=(5, 5), filters=16, padding='same', use_bias=False, dilation_rate=2)(short_cut)
    x = BatchNormalization()(x)
    x3 = PReLU()(x) + short_cut


    short_cut = MaxPool2D(pool_size=(2, 3))(x3)
    x = Conv2D(kernel_size=(5, 5), filters=16, padding='same', use_bias=False, dilation_rate=2)(short_cut)
    x = BatchNormalization()(x)
    x4 = PReLU()(x) + short_cut


    x = Conv2D(kernel_size=(3, 3), filters=16, padding='same')(x4)
    x = BatchNormalization()(x)
    x = Conv2D(kernel_size=(3, 3), filters=8, padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(kernel_size=(3, 3), filters=5, padding='same')(x)
    x = BatchNormalization()(x)
    x = PReLU()(x)
    x = GlobalAveragePooling2D()(x)
    x = Softmax(name='output')(x)

    model = Model(x_input, x)

    model.compile(optimizer = optimizer, loss = keras.losses.categorical_crossentropy, metrics=['acc'])

    return model

# %%
# 모델 실행 옵션 
model = create_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x_input_node (InputLayer)       [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 1200        x_input_node[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, 224, 224, 16) 802816      batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 74, 16)  0           p_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 74, 16)  6400        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 74, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 112, 74, 16)  132608      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 112, 74, 16) 0           p_re_lu_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 24, 16)   0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 24, 16)   6400        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 24, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 56, 24, 16)   21504       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 56, 24, 16)] 0           p_re_lu_2[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 8, 16)    0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 8, 16)    6400        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 8, 16)    64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 28, 8, 16)    3584        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 28, 8, 16)]  0           p_re_lu_3[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 8, 16)    2320        tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 8, 16)    64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 8, 8)     1160        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 8, 8)     32          conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 8, 5)     365         batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 8, 5)     20          conv2d_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 28, 8, 5)     1120        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 5)            0           p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# output (Softmax)                (None, 5)            0           global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 986,249
# Trainable params: 986,063
# Non-trainable params: 186
# __________________________________________________________________________________________________

# %%
checkpoint_path = "check_point/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
#모델의 가중치 저장
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
            monitor='loss', 
            mode='min',
            save_best_only=True,
            save_weights_only=True,
            verbose=1)

#새로운 콜백으로 모델 훈련하기
history = model.fit_generator(train_generator, 
            steps_per_epoch=math.ceil(train_generator.n / train_generator.batch_size), 
            epochs=30, 
            validation_data=val_generator, 
            validation_steps=math.ceil(val_generator.n / val_generator.batch_size), 
            callbacks=[checkpoint],
            shuffle=False)
# Out:
# WARNING:tensorflow:From C:\Users\yukir\AppData\Local\Temp/ipykernel_17352/2427704121.py:16: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
# 332/332 [==============================] - ETA: 0s - loss: 1.5098 - acc: 0.3917
# Epoch 00001: loss improved from inf to 1.50984, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 52ms/step - loss: 1.5098 - acc: 0.3917 - val_loss: 1.5176 - val_acc: 0.1958
# Epoch 2/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.3786 - acc: 0.4469
# Epoch 00002: loss improved from 1.50984 to 1.37863, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 16s 50ms/step - loss: 1.3786 - acc: 0.4470 - val_loss: 1.6802 - val_acc: 0.1834
# Epoch 3/30
# 330/332 [============================>.] - ETA: 0s - loss: 1.2816 - acc: 0.4735
# Epoch 00003: loss improved from 1.37863 to 1.28103, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 1.2810 - acc: 0.4740 - val_loss: 1.3948 - val_acc: 0.3990
# Epoch 4/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.2144 - acc: 0.5008
# Epoch 00004: loss improved from 1.28103 to 1.21427, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 1.2143 - acc: 0.5009 - val_loss: 1.2247 - val_acc: 0.5248
# Epoch 5/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.1511 - acc: 0.5253
# Epoch 00005: loss improved from 1.21427 to 1.15107, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 16s 50ms/step - loss: 1.1511 - acc: 0.5253 - val_loss: 1.3896 - val_acc: 0.4690
# Epoch 6/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.1059 - acc: 0.5417
# Epoch 00006: loss improved from 1.15107 to 1.10581, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 1.1058 - acc: 0.5419 - val_loss: 1.2595 - val_acc: 0.3854
# Epoch 7/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.0554 - acc: 0.5587
# Epoch 00007: loss improved from 1.10581 to 1.05528, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 1.0553 - acc: 0.5589 - val_loss: 1.7384 - val_acc: 0.3110
# Epoch 8/30
# 331/332 [============================>.] - ETA: 0s - loss: 1.0175 - acc: 0.5787
# Epoch 00008: loss improved from 1.05528 to 1.01751, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 1.0175 - acc: 0.5787 - val_loss: 1.2336 - val_acc: 0.4796
# Epoch 9/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.9594 - acc: 0.6080
# Epoch 00009: loss improved from 1.01751 to 0.95932, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.9593 - acc: 0.6080 - val_loss: 2.3052 - val_acc: 0.3668
# Epoch 10/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.9124 - acc: 0.6263
# Epoch 00010: loss improved from 0.95932 to 0.91312, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.9131 - acc: 0.6263 - val_loss: 2.3560 - val_acc: 0.2082
# Epoch 11/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.8774 - acc: 0.6373
# Epoch 00011: loss improved from 0.91312 to 0.87727, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.8773 - acc: 0.6374 - val_loss: 2.0298 - val_acc: 0.4585
# Epoch 12/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.8111 - acc: 0.6690
# Epoch 00012: loss improved from 0.87727 to 0.81123, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.8112 - acc: 0.6689 - val_loss: 1.9681 - val_acc: 0.4473
# Epoch 13/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.7768 - acc: 0.6784
# Epoch 00013: loss improved from 0.81123 to 0.77668, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.7767 - acc: 0.6786 - val_loss: 1.4910 - val_acc: 0.5025
# Epoch 14/30
# 330/332 [============================>.] - ETA: 0s - loss: 0.7039 - acc: 0.7186
# Epoch 00014: loss improved from 0.77668 to 0.70365, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.7036 - acc: 0.7188 - val_loss: 6.4943 - val_acc: 0.4046
# Epoch 15/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.6531 - acc: 0.7500
# Epoch 00015: loss improved from 0.70365 to 0.65341, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.6534 - acc: 0.7499 - val_loss: 1.2623 - val_acc: 0.5372
# Epoch 16/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.5964 - acc: 0.7759
# Epoch 00016: loss improved from 0.65341 to 0.59676, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.5968 - acc: 0.7756 - val_loss: 2.7850 - val_acc: 0.2949
# Epoch 17/30
# 330/332 [============================>.] - ETA: 0s - loss: 0.5370 - acc: 0.8027
# Epoch 00017: loss improved from 0.59676 to 0.53640, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.5364 - acc: 0.8031 - val_loss: 2.8138 - val_acc: 0.3414
# Epoch 18/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.4888 - acc: 0.8216
# Epoch 00018: loss improved from 0.53640 to 0.48882, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.4888 - acc: 0.8214 - val_loss: 2.8818 - val_acc: 0.3401
# Epoch 19/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.4721 - acc: 0.8325
# Epoch 00019: loss improved from 0.48882 to 0.47216, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.4722 - acc: 0.8326 - val_loss: 2.7101 - val_acc: 0.2739
# Epoch 20/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.3939 - acc: 0.8605
# Epoch 00020: loss improved from 0.47216 to 0.39448, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.3945 - acc: 0.8601 - val_loss: 3.0401 - val_acc: 0.3916
# Epoch 21/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.3742 - acc: 0.8695
# Epoch 00021: loss improved from 0.39448 to 0.37446, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.3745 - acc: 0.8694 - val_loss: 2.8112 - val_acc: 0.3055
# Epoch 22/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.3297 - acc: 0.8922
# Epoch 00022: loss improved from 0.37446 to 0.32996, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.3300 - acc: 0.8920 - val_loss: 3.1470 - val_acc: 0.2906
# Epoch 23/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.3382 - acc: 0.8848
# Epoch 00023: loss did not improve from 0.32996
# 332/332 [==============================] - 17s 50ms/step - loss: 0.3383 - acc: 0.8847 - val_loss: 1.7731 - val_acc: 0.4752
# Epoch 24/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.2713 - acc: 0.9114
# Epoch 00024: loss improved from 0.32996 to 0.27120, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.2712 - acc: 0.9115 - val_loss: 5.3460 - val_acc: 0.4275
# Epoch 25/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.2244 - acc: 0.9313
# Epoch 00025: loss improved from 0.27120 to 0.22510, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.2251 - acc: 0.9311 - val_loss: 4.5969 - val_acc: 0.2299
# Epoch 26/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.2391 - acc: 0.9265
# Epoch 00026: loss did not improve from 0.22510
# 332/332 [==============================] - 17s 50ms/step - loss: 0.2395 - acc: 0.9262 - val_loss: 3.6815 - val_acc: 0.4696
# Epoch 27/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.1897 - acc: 0.9435
# Epoch 00027: loss improved from 0.22510 to 0.18977, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.1898 - acc: 0.9436 - val_loss: 10.7048 - val_acc: 0.4126
# Epoch 28/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.1677 - acc: 0.9515
# Epoch 00028: loss improved from 0.18977 to 0.16776, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 50ms/step - loss: 0.1678 - acc: 0.9515 - val_loss: 7.7701 - val_acc: 0.3123
# Epoch 29/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.1368 - acc: 0.9600
# Epoch 00029: loss improved from 0.16776 to 0.13680, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.1368 - acc: 0.9600 - val_loss: 7.8473 - val_acc: 0.0843
# Epoch 30/30
# 331/332 [============================>.] - ETA: 0s - loss: 0.1278 - acc: 0.9653
# Epoch 00030: loss improved from 0.13680 to 0.12816, saving model to check_point/cp.ckpt
# 332/332 [==============================] - 17s 51ms/step - loss: 0.1282 - acc: 0.9651 - val_loss: 2.2391 - val_acc: 0.4139

# %% [markdown]
# ### RESULT

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) +1)
    
    

fig = plt.figure()
fig.set_size_inches(15, 5)

fig.add_subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label ='Training acc')
plt.plot(epochs, val_acc, 'r', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

# plt.figure()
fig.add_subplot(1, 2, 2) 
plt.plot(epochs, loss, 'b', label = "Training loss")
plt.plot(epochs, val_loss, 'r', label ='Validation loss')
plt.title('Training and validation lose')
plt.legend()

plt.show()

# %%
os.listdir(test_dir)
# Out:
# ['0', '1', '2', '3', '4']

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    classes=['0', '1', '2', '3', '4']
    print ('*** classes ', classes)
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            file_id=os.path.split(file_names[i])[1]
            error_list.append(file_id)
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(error_list[i], pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    if len(classes)<= 20:
        # create a confusion matrix and a test report        
        y_true= np.array(labels)        
        y_pred=np.array(y_pred)        
        cm = confusion_matrix(y_true, y_pred )
        clr = classification_report(y_true, y_pred, target_names=classes)
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width=length
            fig_height=length
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()    
        print("Classification Report:\n----------------------\n", clr)

# %%
save_dir = 'C:\\Users\\yukir\\Documents\\Monicas_workspace\\Knee'
subject='knees'

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %%
preds=model.predict(test_generator, batch_size=16, verbose=0, steps=1302/16)
print_code=10
print_info( test_generator, preds, print_code, save_dir, subject )
# Out:
# *** classes  ['0', '1', '2', '3', '4']
#           Filename                Predicted Class                True Class           Probability
#
#        0_9003126R.jpg                    2                           0                  0.6104
#
#        0_9003658L.jpg                    1                           0                  0.6186
#
#        0_9005075R.jpg                    1                           0                  0.5338
#
#        0_9007904R.jpg                    2                           0                  0.7407
#
#        0_9009067L.jpg                    2                           0                  0.9949
#
#        0_9009067R.jpg                    1                           0                  0.7386
#
#        0_9011115L.jpg                    2                           0                  0.9488
#
#        0_9011949R.jpg                    2                           0                  0.9731
#
#        0_9015718R.jpg                    2                           0                  0.9053
#
#        0_9016121R.jpg                    2                           0                  0.9496
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#            0       0.39      0.29      0.33       523
#            1       0.18      0.34      0.23       244
#            2       0.24      0.26      0.25       342
#            3       0.11      0.04      0.06       171
#            4       0.04      0.05      0.04        22
#
#     accuracy                           0.25      1302
#    macro avg       0.19      0.19      0.18      1302
# weighted avg       0.27      0.25      0.25      1302
